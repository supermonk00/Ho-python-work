# %%
x<-c(1:100)

# %%
y<-sample(1:100,100)

# %%
plot(x,y)
# Out:
# plot without title

# %%
install.packages("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(ggplot2)

# %%
qqplot(aes(x),y)
# Out:
# Error in xy.coords(x, y, xlabel, ylabel, log): (串列) 物件無法強制變更成 'double'
# Traceback:
#
# 1. qqplot(aes(x), y)
# 2. plot(sx, sy, xlab = xlab, ylab = ylab, ...)
# 3. plot.default(sx, sy, xlab = xlab, ylab = ylab, ...)
# 4. xy.coords(x, y, xlabel, ylabel, log)
